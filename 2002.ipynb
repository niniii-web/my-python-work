# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-30,20,100)
y = np.linspace(-30,20,100)

X,Y =np.meshgrid(x,y)
Z = X**2+Y**2

# %%
plt.figure(figsize=(12,6))
plt.contourf(X,Y,Z)
plt.contour(X,Y,Z)
