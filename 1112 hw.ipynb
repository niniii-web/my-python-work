# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 分析桃園市各區結婚統計

# %%
df =pd.read_csv('https://data.tycg.gov.tw/opendata/datalist/datasetMeta/download?id=f95d1a33-ec56-44c5-a9ec-3afba8157e39&rid=3e9f6bb6-3531-4f54-aee7-fca697a0dfeb')

# %%
df
# Out:
#    月份區域別   一月   二月   四月   五月   六月   七月   八月   九月   十月  十一月  十二月
# 0    桃園市  336  125  200  324  148  198   99  250  239  326  296
# 1    中壢市  281  125  163  331  158  220  118  246  279  272  243
# 2    平鎮市  159   73  106  148  112  112   60  124  136  152  170
# 3    八德市  145   60  100  160   72  100   51  110  125  113  122
# 4    楊梅市  113   38   61  109   59   67   42  108  116  115   83
# 5    大溪鎮   66   28   49   58   35   51   23   49   57   42   49
# 6    蘆竹鄉   96   62   91  103   61   74   57   76   78  102  105
# 7    大園鄉   68   30   31   55   32   43   19   53   44   51   49
# 8    龜山鄉  108   57   61  119   61   76   42  103  114  101   93
# 9    龍潭鄉   72   34   65   77   40   49   31   69   45   91   81
# 10   新屋鄉   30    9   10   21   20   16    8   17   28   30   24
# 11   觀音鄉   43   14   35   40   27   30   18   33   31   35   40
# 12   復興鄉   11    5    4    8    9    8    4    5    6    5    5

# %%
len(df)
# Out:
# 13

# %%
df.head()
# Out:
#   月份區域別   一月   二月   四月   五月   六月   七月   八月   九月   十月  十一月  十二月
# 0   桃園市  336  125  200  324  148  198   99  250  239  326  296
# 1   中壢市  281  125  163  331  158  220  118  246  279  272  243
# 2   平鎮市  159   73  106  148  112  112   60  124  136  152  170
# 3   八德市  145   60  100  160   72  100   51  110  125  113  122
# 4   楊梅市  113   38   61  109   59   67   42  108  116  115   83

# %% [markdown]
# ## 刪除指定月份數據

# %%
df=df.drop("三月",axis=1)

# %%
df.head()
# Out:
#   月份區域別   一月   二月   四月   五月   六月   七月   八月   九月   十月  十一月  十二月
# 0   桃園市  336  125  200  324  148  198   99  250  239  326  296
# 1   中壢市  281  125  163  331  158  220  118  246  279  272  243
# 2   平鎮市  159   73  106  148  112  112   60  124  136  152  170
# 3   八德市  145   60  100  160   72  100   51  110  125  113  122
# 4   楊梅市  113   38   61  109   59   67   42  108  116  115   83

# %% [markdown]
# ## 二月結婚數最多的地區

# %%
df[df['二月']==df['二月'].max()]
# Out:
#   月份區域別   一月   二月   四月   五月   六月   七月   八月   九月   十月  十一月  十二月
# 0   桃園市  336  125  200  324  148  198   99  250  239  326  296
# 1   中壢市  281  125  163  331  158  220  118  246  279  272  243

# %% [markdown]
# ## 六月結婚數量最少的五個區

# %%
df_sorted=df.sort_values(by=["六月"],ascending=False)

# %%
df.tail()
# Out:
#    月份區域別   一月  二月  四月   五月  六月  七月  八月   九月   十月  十一月  十二月
# 8    龜山鄉  108  57  61  119  61  76  42  103  114  101   93
# 9    龍潭鄉   72  34  65   77  40  49  31   69   45   91   81
# 10   新屋鄉   30   9  10   21  20  16   8   17   28   30   24
# 11   觀音鄉   43  14  35   40  27  30  18   33   31   35   40
# 12   復興鄉   11   5   4    8   9   8   4    5    6    5    5

# %% [markdown]
# ## 六月結婚數量最多的五個區

# %%
df_sorted=df.sort_values(by=["六月"],ascending=False)

# %%
df.head()
# Out:
#   月份區域別   一月   二月   四月   五月   六月   七月   八月   九月   十月  十一月  十二月
# 0   桃園市  336  125  200  324  148  198   99  250  239  326  296
# 1   中壢市  281  125  163  331  158  220  118  246  279  272  243
# 2   平鎮市  159   73  106  148  112  112   60  124  136  152  170
# 3   八德市  145   60  100  160   72  100   51  110  125  113  122
# 4   楊梅市  113   38   61  109   59   67   42  108  116  115   83

# %% [markdown]
# ## 資料繪圖

# %%
df.一月.plot(color='b'),df.二月.plot(color='r'),df.四月.plot(color='g'),df.五月.plot(color='y')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x11fa40be0>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x11fa40be0>)
