# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sympy as sp

# %% [markdown]
# ### 函數繪圖

# %%
x=sp.symbols("x")
y=input("函數式：")
sp.plot(y)
# Out:
# 函數式：x**4+x**2+x*8+9
